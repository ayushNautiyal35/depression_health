# %%
import pandas as pd

# %%
data=pd.read_csv("train.csv")

# %%
data.head(3)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
#
#   Profession  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       Chef                NaN            5.0   NaN                 NaN
# 1    Teacher                NaN            4.0   NaN                 NaN
# 2        NaN                5.0            NaN  8.97                 2.0
#
#    Job Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0               2.0  More than 8 hours        Healthy      BHM
# 1               3.0  Less than 5 hours      Unhealthy      LLB
# 2               NaN          5-6 hours        Healthy  B.Pharm
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140700 entries, 0 to 140699
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   id                                     140700 non-null  int64
#  1   Name                                   140700 non-null  object
#  2   Gender                                 140700 non-null  object
#  3   Age                                    140700 non-null  float64
#  4   City                                   140700 non-null  object
#  5   Working Professional or Student        140700 non-null  object
#  6   Profession                             104070 non-null  object
#  7   Academic Pressure                      27897 non-null   float64
#  8   Work Pressure                          112782 non-null  float64
#  9   CGPA                                   27898 non-null   float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data=data.drop('id',axis=1)
data=data.drop('Name',axis=1)

# %%
data.isnull().sum()
# Out:
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                36630
# Academic Pressure                        112803
# Work Pressure                             27918
# CGPA                                     112802
# Study Satisfaction                       112803
# Job Satisfaction                          27910
# Sleep Duration                                0
# Dietary Habits                                4
# Degree                                        2
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Depression                                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# For gender

# %%
gender_counts=data['Gender'].value_counts()
plt.bar(gender_counts.index,gender_counts.values)


plt.plot()
# Out:
# []

# %%
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.1f%%')

plt.plot()
# Out:
# []

# %%
data['Gender']=data['Gender'].map({'Male':0,'Female':1})

# %%
data['Gender'].value_counts()
# Out:
# Gender
# 0    77464
# 1    63236
# Name: count, dtype: int64

# %%
data['Gender'].corr(data['Depression'])
# Out:
# -0.008144029348599252

# %%
import seaborn as sns

# %%
sns.lineplot(x=data['Gender'],y=data['Depression'])
# Out:
# <Axes: xlabel='Gender', ylabel='Depression'>

# %% [markdown]
# For age

# %%
data['Age'].describe()
# Out:
# count    140700.000000
# mean         40.388621
# std          12.384099
# min          18.000000
# 25%          29.000000
# 50%          42.000000
# 75%          51.000000
# max          60.000000
# Name: Age, dtype: float64

# %%
data['Age'].mode()
# Out:
# 0    56.0
# Name: Age, dtype: float64

# %%
plt.hist(data['Age'])
# Out:
# (array([14878., 11294., 10960., 10063., 12825., 16745., 15031., 16160.,
#         13889., 18855.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
bins=[10,20,30,40,50,60,70,80]
labels=['10-20','21-30','31-40','41-50','51-60','61-70','71-80']
data['Age']=pd.cut(data['Age'],bins=bins,labels=labels)
data['Age'].value_counts()
# Out:
# Age
# 41-50    37653
# 51-60    36671
# 31-40    29244
# 21-30    27062
# 10-20    10070
# 61-70        0
# 71-80        0
# Name: count, dtype: int64

# %%
age_counts=data['Age'].value_counts()
plt.bar(age_counts.index,age_counts.values)
plt.plot()
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder
lb_age=LabelEncoder()
data['Age']=lb_age.fit_transform(data['Age'])

# %%
data['Age'].value_counts()
# Out:
# Age
# 3    37653
# 4    36671
# 2    29244
# 1    27062
# 0    10070
# Name: count, dtype: int64

# %%
data['Age'].corr(data['Depression'])
# Out:
# -0.5542260632870881

# %%
sns.lineplot(x=data['Age'],y=data['Depression'])
# Out:
# <Axes: xlabel='Age', ylabel='Depression'>

# %% [markdown]
# For City

# %%
city_counts=data['City'].value_counts()

# %%
fig, axs = plt.subplots( figsize=(20, 8))
axs.bar(city_counts.index,city_counts.values)
plt.xticks(rotation=90)
plt.show()

# %%
print(city_counts.index)
# Out:
# Index(['Kalyan', 'Patna', 'Vasai-Virar', 'Kolkata', 'Ahmedabad', 'Meerut',
#        'Ludhiana', 'Pune', 'Rajkot', 'Visakhapatnam', 'Srinagar', 'Mumbai',
#        'Indore', 'Agra', 'Surat', 'Varanasi', 'Vadodara', 'Hyderabad',
#        'Kanpur', 'Jaipur', 'Thane', 'Lucknow', 'Nagpur', 'Bangalore',
#        'Chennai', 'Ghaziabad', 'Delhi', 'Bhopal', 'Faridabad', 'Nashik',
#        'Mihir', 'Nandini', 'Mahi', 'Vidya', 'City', 'Pratyush', 'Harsha',
#        'Saanvi', 'Bhavna', 'Molkata', 'MCA', 'M.Com', 'Atharv', 'Nalini',
#        'Keshav', 'Ayush', 'M.Tech', 'Researcher', 'Vaishnavi', 'Chhavi',
#        'Parth', 'Vidhi', 'Tushar', 'MSc', 'No', 'Rashi', 'ME', 'Ishanabad',
#        'Armaan', 'Kagan', 'Kashish', 'Ithal', 'Nalyan', 'Dhruv', 'Galesabad',
#        'Itheg', 'Aaradhya', 'Pooja', 'Khushi', 'Khaziabad', 'Jhanvi', 'Kibara',
#        'Harsh', 'Reyansh', 'Morena', 'Less Delhi', 'Malyansh', 'Aditya',
#        'Plata', 'Aishwarya', '3.0', 'Less than 5 Kalyan', 'Krishna', 'Mira',
# ...

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
valid_city=['Kalyan', 'Patna', 'Vasai-Virar', 'Kolkata', 'Ahmedabad', 'Meerut',
       'Ludhiana', 'Pune', 'Rajkot', 'Visakhapatnam', 'Srinagar', 'Mumbai',
       'Indore', 'Agra', 'Surat', 'Varanasi', 'Vadodara', 'Hyderabad',
       'Kanpur', 'Jaipur', 'Thane', 'Lucknow', 'Nagpur', 'Bangalore',
       'Chennai', 'Ghaziabad', 'Delhi', 'Bhopal', 'Faridabad', 'Nashik','Gurgaon']
dict_city={}
c=0
for i in valid_city:
    dict_city[i]=c
    c+=1
dict_city['others']=c

def change_city(city):
    if city in dict_city:
        return dict_city[city]
    else:
        return dict_city['others']
    
data['City']=data['City'].apply(change_city).values

# %%
data['City'].value_counts()
# Out:
# City
# 0     6591
# 1     5924
# 2     5765
# 3     5689
# 4     5613
# 5     5528
# 6     5226
# 7     5210
# 8     5207
# 9     5176
# 10    5074
# 11    4966
# 12    4872
# 13    4684
# 14    4636
# 15    4606
# 16    4568
# 17    4496
# 18    4398
# 19    4328
# 20    4289
# 21    4280
# 22    4209
# 23    4123
# 24    4044
# 25    3620
# 26    3593
# 27    3475
# 28    3268
# 29    3144
# 31      97
# 30       1
# Name: count, dtype: int64

# %%
data['City'].corr(data['Depression'])
# Out:
# 0.006597071692164129

# %%
sns.lineplot(x=data['City'],y=data['Depression'])
# Out:
# <Axes: xlabel='City', ylabel='Depression'>

# %% [markdown]
# Profession

# %%
c=0
for i in data['Working Professional or Student']:
    if i == "Student":
        data['Profession'][c]="Student"
    c+=1

# %%
data.drop('Working Professional or Student',axis=1,inplace=True)

# %%
data[data['Profession'].isnull()]
# Out:
#         Gender  Age  City Profession  Academic Pressure  Work Pressure  CGPA  \
# 29           1    0    13        NaN                NaN            1.0   NaN
# 36           1    3     0        NaN                NaN            4.0   NaN
# 43           1    0    16        NaN                NaN            5.0   NaN
# 48           0    2    25        NaN                NaN            2.0   NaN
# 50           0    1     7        NaN                NaN            4.0   NaN
# ...        ...  ...   ...        ...                ...            ...   ...
# 140647       0    2     8        NaN                NaN            5.0   NaN
# 140655       0    3     5        NaN                NaN            1.0   NaN
# 140666       0    0    16        NaN                NaN            5.0   NaN
# 140667       1    0     8        NaN                NaN            4.0   NaN
# 140695       1    0     4        NaN                NaN            5.0   NaN
#
# ...

# %%
data['Profession'].value_counts().index
# Out:
# Index(['Student', 'Teacher', 'Content Writer', 'Architect', 'Consultant',
#        'HR Manager', 'Pharmacist', 'Doctor', 'Business Analyst', 'Chemist',
#        'Entrepreneur', 'Chef', 'Educational Consultant', 'Data Scientist',
#        'Researcher', 'Lawyer', 'Customer Support', 'Marketing Manager',
#        'Pilot', 'Travel Consultant', 'Plumber', 'Sales Executive', 'Manager',
#        'Judge', 'Electrician', 'Financial Analyst', 'Software Engineer',
#        'Civil Engineer', 'UX/UI Designer', 'Digital Marketer', 'Accountant',
#        'Finanancial Analyst', 'Mechanical Engineer', 'Graphic Designer',
#        'Research Analyst', 'Investment Banker', 'Academic', 'Unemployed',
#        'Yogesh', 'Profession', 'BCA', 'MBA', 'LLM', 'PhD', 'Analyst', 'Patna',
#        'Pranav', 'Visakhapatnam', 'M.Ed', 'Moderate', 'Nagpur', 'B.Ed',
#        'Unveil', 'BBA', 'MBBS', 'Working Professional', 'Medical Doctor',
#        'City Manager', 'FamilyVirar', 'Dev', 'BE', 'B.Com',
# ...

# %%
data['Profession']=data['Profession'].fillna('others')

# %%
profession_counts=data['Profession'].value_counts()
fig, axs = plt.subplots( figsize=(20, 8))
axs.bar(profession_counts.index,profession_counts.values)
plt.xticks(rotation=90)
plt.show()

# %%
dict_profession={}
c=0
for i in data['Profession'].value_counts().index:
    dict_profession[i]=c
    c+=1

# %%
data['Profession']=data['Profession'].map(dict_profession)

# %%
data['Profession'].corr(data['Depression'])
# Out:
# -0.2536791324542748

# %%
sns.lineplot(x=data['Profession'],y=data['Depression'])
# Out:
# <Axes: xlabel='Profession', ylabel='Depression'>

# %% [markdown]
# Pressure

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0       1    3     6          12                NaN            5.0   NaN
# 1       0    1    15           1                NaN            4.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# 1                 NaN               3.0  Less than 5 hours      Unhealthy
#
#   Degree Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0    BHM                                    No               1.0
# 1    LLB                                   Yes               7.0
#
#    Financial Stress Family History of Mental Illness  Depression
# 0               2.0                               No           0
# 1               3.0                               No           1

# %%
data['Work Pressure'].isnull().sum()
# Out:
# 27918

# %%
data['Age'].size-data['Academic Pressure'].isnull().sum()
# Out:
# 27897

# %%
import numpy as np
import math
c=0
for i in data['Academic Pressure']:
    if math.isnan(i) == False:
        data['Work Pressure'][c]=data['Academic Pressure'][c]
    c+=1

# %%
data[data['Work Pressure'].isnull()]
# Out:
#         Gender  Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 15846        0    4     2           2                NaN            NaN   NaN
# 17549        1    0     1           0                NaN            NaN  5.55
# 34694        1    3     5           2                NaN            NaN   NaN
# 35612        0    1    16           2                NaN            NaN   NaN
# 57196        1    0     9           2                NaN            NaN   NaN
# 60348        0    1    13           2                NaN            NaN  9.72
# 70453        1    0     4           0                NaN            NaN   NaN
# 76104        1    0    29           2                NaN            NaN   NaN
# 85126        1    1    18          33                NaN            NaN   NaN
# 86606        0    0    20           2                NaN            NaN   NaN
# 92609        1    4    12           2                NaN            NaN   NaN
# ...

# %%
data.drop('Academic Pressure',axis=1,inplace=True)

# %%
data['Work Pressure'].describe()
# Out:
# count    140679.000000
# mean          3.027410
# std           1.401947
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Work Pressure, dtype: float64

# %%
data['Work Pressure'].value_counts()
# Out:
# Work Pressure
# 3.0    29362
# 5.0    28732
# 2.0    28552
# 4.0    27670
# 1.0    26363
# Name: count, dtype: int64

# %%
work_counts=data['Work Pressure'].value_counts()
plt.bar(work_counts.index,work_counts.values)
plt.show()

# %%
data['Work Pressure']=data['Work Pressure'].fillna(3.0)

# %%
data['Work Pressure'].corr(data['Depression'])
# Out:
# 0.26345236532449734

# %%
sns.lineplot(x=data['Work Pressure'],y=data['Depression'])
plt.show()

# %%
data.drop('CGPA',axis=1,inplace=True)

# %% [markdown]
# Satisfaction

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Study Satisfaction  \
# 0       1    3     6          12            5.0                 NaN
# 1       0    1    15           1            4.0                 NaN
#
#    Job Satisfaction     Sleep Duration Dietary Habits Degree  \
# 0               2.0  More than 8 hours        Healthy    BHM
# 1               3.0  Less than 5 hours      Unhealthy    LLB
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               1.0               2.0
# 1                                   Yes               7.0               3.0
#
#   Family History of Mental Illness  Depression
# 0                               No           0
# 1                               No           1

# %%
data['Job Satisfaction'].isnull().sum()
# Out:
# 27910

# %%
c=0

for i in data['Study Satisfaction']:
    if math.isnan(i) == False:
        data['Job Satisfaction'][c]=i
    c+=1

print(data['Job Satisfaction'].isnull().sum())
# Out:
# 15

# %%
data.drop('Study Satisfaction',axis=1,inplace=True)

# %%
data['Job Satisfaction'].describe()
# Out:
# count    140685.000000
# mean          2.968568
# std           1.405226
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Job Satisfaction, dtype: float64

# %%
data['Job Satisfaction'].value_counts()
# Out:
# Job Satisfaction
# 2.0    30622
# 1.0    27775
# 3.0    27773
# 4.0    27280
# 5.0    27235
# Name: count, dtype: int64

# %%
job_counts=data['Job Satisfaction'].value_counts()
plt.bar(job_counts.index,job_counts.values)
plt.show()

# %%
data['Job Satisfaction']=data['Job Satisfaction'].fillna(3.0)

# %%
data['Job Satisfaction'].corr(data['Depression'])
# Out:
# -0.14231383455499286

# %%
sns.lineplot(x=data['Job Satisfaction'],y=data['Depression'])
plt.show()

# %% [markdown]
# For sleep duration

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#       Sleep Duration Dietary Habits Degree  \
# 0  More than 8 hours        Healthy    BHM
# 1  Less than 5 hours      Unhealthy    LLB
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               1.0               2.0
# 1                                   Yes               7.0               3.0
#
#   Family History of Mental Illness  Depression
# 0                               No           0
# 1                               No           1

# %%
data['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    38784
# 7-8 hours            36969
# More than 8 hours    32726
# 5-6 hours            32142
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 2-3 hours                5
# 4-6 hours                5
# 6-8 hours                4
# 1-6 hours                4
# No                       4
# 9-11 hours               2
# 10-11 hours              2
# Sleep_Duration           2
# Unhealthy                2
# 45                       2
# 8-9 hours                2
# 10-6 hours               1
# 9-5                      1
# 45-48 hours              1
# 3-6 hours                1
# Work_Study_Hours         1
# 49 hours                 1
# than 5 hours             1
# Pune                     1
# 9-6 hours                1
# 8 hours                  1
# 35-36 hours              1
# Indore                   1
# 1-3 hours                1
# 55-66 hours              1
# Moderate                 1
# ...

# %%
sleep_counts=data['Sleep Duration'].value_counts()

plt.bar(sleep_counts.index,sleep_counts.values)
plt.xticks(rotation=90)
plt.show()

# %%
dict_sleep={'Less than 5 hours':0,'7-8 hours':1,'More than 8 hours':2,'5-6 hours':3,'Others':4}

def change_sleep(s):
    if s in dict_sleep:
        return dict_sleep[s]
    else:
        return dict_sleep['Others']

data['Sleep Duration']=data['Sleep Duration'].apply(change_sleep).values

# %%
plt.pie(data['Sleep Duration'].value_counts().values,labels=data['Sleep Duration'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
data['Sleep Duration'].corr(data['Depression'])
# Out:
# -0.07414466510138142

# %%
sns.violinplot(x=data['Sleep Duration'],y=data['Depression'])
plt.show()

# %% [markdown]
# For dietary

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#    Sleep Duration Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 0               2        Healthy    BHM                                    No
# 1               0      Unhealthy    LLB                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               1.0               2.0                               No
# 1               7.0               3.0                               No
#
#    Depression
# 0           0
# 1           1

# %%
diet_counts=data['Dietary Habits'].value_counts()
plt.bar(diet_counts.index,diet_counts.values)
plt.xticks(rotation=90)
plt.show()

# %%
data['Dietary Habits'].isnull().sum()
# Out:
# 4

# %%
data['Dietary Habits']=data['Dietary Habits'].fillna('Moderate')

# %%
dict_diet={'Moderate':0, 'Unhealthy':1, 'Healthy':2,'Others':3}

def change_diet(d):
    if d in dict_diet:
        return dict_diet[d]
    else:
        return dict_diet['Others']
    
data['Dietary Habits']=data['Dietary Habits'].apply(change_diet)

# %%
data['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# 0    49709
# 1    46227
# 2    44741
# 3       23
# Name: count, dtype: int64

# %%
data['Dietary Habits'].corr(data['Depression'])
# Out:
# -0.04603767477702668

# %%
sns.lineplot(x=data['Dietary Habits'],y=data['Depression'])
plt.show()

# %%
sns.violinplot(x=data['Dietary Habits'],y=data['Depression'])
plt.show()

# %%
data.drop('Degree',axis=1,inplace=True)

# %% [markdown]
# For thoughts

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#    Sleep Duration  Dietary Habits Have you ever had suicidal thoughts ?  \
# 0               2               2                                    No
# 1               0               1                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               1.0               2.0                               No
# 1               7.0               3.0                               No
#
#    Depression
# 0           0
# 1           1

# %%
thoughts_counts=data['Have you ever had suicidal thoughts ?'].value_counts()
plt.bar(thoughts_counts.index,thoughts_counts.values)
plt.show()

# %%
data['Have you ever had suicidal thoughts ?']=data['Have you ever had suicidal thoughts ?'].map({'No':0,'Yes':1})

# %%
data['Have you ever had suicidal thoughts ?'].value_counts()
# Out:
# Have you ever had suicidal thoughts ?
# 0    71138
# 1    69562
# Name: count, dtype: int64

# %%
data['Have you ever had suicidal thoughts ?'].corr(data['Depression'])
# Out:
# 0.3490658250443482

# %%
sns.lineplot(x=data['Have you ever had suicidal thoughts ?'],y=data['Depression'])
plt.show()

# %%
sns.violinplot(x=data['Have you ever had suicidal thoughts ?'],y=data['Depression'])
plt.show()

# %% [markdown]
# For work/study hrs

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#    Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0               2               2                                      0
# 1               0               1                                      1
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               1.0               2.0                               No
# 1               7.0               3.0                               No
#
#    Depression
# 0           0
# 1           1

# %%
hrs_counts=data['Work/Study Hours'].value_counts()
plt.bar(hrs_counts.index,hrs_counts.values)
plt.show()

# %%
data['Work/Study Hours'].describe()
# Out:
# count    140700.000000
# mean          6.252679
# std           3.853615
# min           0.000000
# 25%           3.000000
# 50%           6.000000
# 75%          10.000000
# max          12.000000
# Name: Work/Study Hours, dtype: float64

# %%
data['Work/Study Hours'].corr(data['Depression'])
# Out:
# 0.19174619566204804

# %%
sns.lineplot(x=data['Work/Study Hours'],y=data['Depression'])
plt.show()

# %% [markdown]
# For financial stress

# %%
data.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#    Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0               2               2                                      0
# 1               0               1                                      1
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               1.0               2.0                               No
# 1               7.0               3.0                               No
#
#    Depression
# 0           0
# 1           1

# %%
fin_counts=data['Financial Stress'].value_counts()
plt.bar(fin_counts.index,fin_counts.values)
plt.show()

# %%
data['Financial Stress'].isnull().sum()
# Out:
# 4

# %%
data['Financial Stress'].describe()
# Out:
# count    140696.000000
# mean          2.988983
# std           1.413633
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Financial Stress, dtype: float64

# %%
data['Financial Stress']=data['Financial Stress'].fillna(3.0)

# %%
data['Financial Stress'].value_counts()
# Out:
# Financial Stress
# 2.0    31451
# 5.0    28279
# 4.0    27765
# 1.0    27211
# 3.0    25994
# Name: count, dtype: int64

# %%
data['Financial Stress'].corr(data['Depression'])
# Out:
# 0.22723240661826338

# %%
sns.lineplot(x=data['Financial Stress'],y=data['Depression'])
plt.show()

# %% [markdown]
# For family history

# %%
fam_counts=data['Family History of Mental Illness'].value_counts()
plt.bar(fam_counts.index,fam_counts.values)
plt.show()

# %%
data['Family History of Mental Illness']=data['Family History of Mental Illness'].map({'No':0,'Yes':1})

# %%
data['Family History of Mental Illness'].value_counts()
# Out:
# Family History of Mental Illness
# 0    70758
# 1    69942
# Name: count, dtype: int64

# %%
data['Family History of Mental Illness'].corr(data['Depression'])
# Out:
# 0.016501570274886312

# %%
sns.lineplot(x=data['Family History of Mental Illness'],y=data['Depression'])
plt.show()

# %% [markdown]
# Dividing into train and validation set

# %%
x=data.drop('Depression',axis=1)
y=data['Depression']

# %%
x.head(2)
# Out:
#    Gender  Age  City  Profession  Work Pressure  Job Satisfaction  \
# 0       1    3     6          12            5.0               2.0
# 1       0    1    15           1            4.0               3.0
#
#    Sleep Duration  Dietary Habits  Have you ever had suicidal thoughts ?  \
# 0               2               2                                      0
# 1               0               1                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness
# 0               1.0               2.0                                 0
# 1               7.0               3.0                                 0

# %%
y.head(2)
# Out:
# 0    0
# 1    1
# Name: Depression, dtype: int64

# %%
y.value_counts()
# Out:
# Depression
# 0    115133
# 1     25567
# Name: count, dtype: int64

# %% [markdown]
# Making data balanced

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
x,y=smote.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Depression
# 0    115133
# 1    115133
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=32)

# %%
x_train.size
# Out:
# 1657908

# %%
x_test.size
# Out:
# 1105284

# %% [markdown]
# Training ml model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score

# %%
def check(model):
    y_pred=model.predict(x_test)
    print("The precision score: ", precision_score(y_test,y_pred))
    print("The recall score: ",recall_score(y_test,y_pred))
    print("The confusion matrix: ",confusion_matrix(y_test,y_pred))
    print("The accuracy score: ",accuracy_score(y_test,y_pred))

# %% [raw]
# from sklearn.linear_model import LogisticRegressionCV
# check(LogisticRegressionCV().fit(x_train,y_train))

# %% [raw]
# from sklearn.linear_model import PassiveAggressiveClassifier
# check(PassiveAggressiveClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.linear_model import RidgeClassifier
# check(RidgeClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.naive_bayes import GaussianNB
# check(GaussianNB().fit(x_train,y_train))

# %% [raw]
# from sklearn.neighbors import KNeighborsClassifier
# check(KNeighborsClassifier(4).fit(x_train,y_train))

# %% [raw]
# from sklearn.svm import SVC
# check(SVC().fit(x_train,y_train))

# %% [raw]
# from sklearn.tree import DecisionTreeClassifier
# check(DecisionTreeClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import AdaBoostClassifier
# check(AdaBoostClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import BaggingClassifier
# check(BaggingClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import ExtraTreesClassifier
# check(ExtraTreesClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import GradientBoostingClassifier
# check(GradientBoostingClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import HistGradientBoostingClassifier
# check(HistGradientBoostingClassifier().fit(x_train,y_train))

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier
# check(RandomForestClassifier().fit(x_train,y_train))

# %% [raw]
# from xgboost import XGBClassifier
# check(XGBClassifier().fit(x_train,y_train))

# %%
from catboost import CatBoostClassifier
check(CatBoostClassifier().fit(x_train,y_train))
# Out:
# The precision score:  0.9606724445799399
# The recall score:  0.9576070676593805
# The confusion matrix:  [[44232  1806]
#  [ 1953 44116]]
# The accuracy score:  0.9591887695832021

# %%
final_model_ml=CatBoostClassifier().fit(x,y)

# %% [markdown]
# Now for deep learning

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Flatten, BatchNormalization,Dropout
from keras.callbacks import EarlyStopping

# %% [raw]
# from kerastuner.tuners import RandomSearch
#
# def build_model(hp):
#     model = Sequential([
#         Dense(hp.Int('units', min_value=32, max_value=256, step=32), activation='relu', input_shape=(12,)),
#         Dense(1, activation='sigmoid')
#     ])
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#     return model
#
# tuner = RandomSearch(
#     build_model,
#     objective='val_accuracy',
#     max_trials=10,
#     directory='my_dir',
#     project_name='binary_classification'
# )
#
# tuner.search(x, y, epochs=20, validation_split=0.3)

# %% [raw]
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
classifier = tuner.hypermodel.build(best_hps)
history = classifier.fit(
    x,y,
    validation_split=0.34,
    epochs=50,  # Use an adequate number of epochs
    batch_size=32,  # Or use a value from the best_hps
    
)
# Out:
# Epoch 1/50
# 4750/4750 [==============================] - 8s 2ms/step - loss: 0.1935 - accuracy: 0.9214 - val_loss: 0.2059 - val_accuracy: 0.9206
# Epoch 2/50
# 4750/4750 [==============================] - 8s 2ms/step - loss: 0.1785 - accuracy: 0.9283 - val_loss: 0.2511 - val_accuracy: 0.9012
# Epoch 3/50
# 4750/4750 [==============================] - 7s 1ms/step - loss: 0.1767 - accuracy: 0.9287 - val_loss: 0.2454 - val_accuracy: 0.9028
# Epoch 4/50
# 4750/4750 [==============================] - 8s 2ms/step - loss: 0.1755 - accuracy: 0.9293 - val_loss: 0.3205 - val_accuracy: 0.8665
# Epoch 5/50
# 4750/4750 [==============================] - 7s 1ms/step - loss: 0.1745 - accuracy: 0.9300 - val_loss: 0.2469 - val_accuracy: 0.9009
# Epoch 6/50
# 4750/4750 [==============================] - 8s 2ms/step - loss: 0.1737 - accuracy: 0.9303 - val_loss: 0.4203 - val_accuracy: 0.8214
# Epoch 7/50
# ...

# %% [markdown]
# Testing model and preparing result

# %%
test=pd.read_csv("test.csv")

# %%
test.head(2)
# Out:
#        id    Name  Gender   Age           City  \
# 0  140700  Shivam    Male  53.0  Visakhapatnam
# 1  140701   Sanya  Female  58.0        Kolkata
#
#   Working Professional or Student              Profession  Academic Pressure  \
# 0            Working Professional                   Judge                NaN
# 1            Working Professional  Educational Consultant                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            2.0   NaN                 NaN               5.0
# 1            2.0   NaN                 NaN               4.0
#
#       Sleep Duration Dietary Habits Degree  \
# 0  Less than 5 hours       Moderate    LLB
# 1  Less than 5 hours       Moderate   B.Ed
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No               9.0               3.0
# 1                                    No               6.0               4.0
#
# ...

# %%
test.isnull().sum()
# Out:
# id                                           0
# Name                                         0
# Gender                                       0
# Age                                          0
# City                                         0
# Working Professional or Student              0
# Profession                               24632
# Academic Pressure                        75033
# Work Pressure                            18778
# CGPA                                     75034
# Study Satisfaction                       75033
# Job Satisfaction                         18774
# Sleep Duration                               0
# Dietary Habits                               5
# Degree                                       2
# Have you ever had suicidal thoughts ?        0
# Work/Study Hours                             0
# Financial Stress                             0
# Family History of Mental Illness             0
# dtype: int64

# %%
test['Gender']=test['Gender'].map({'Male':0,'Female':1})

# %%
bins=[10,20,30,40,50,60,70,80]
labels=['10-20','21-30','31-40','41-50','51-60','61-70','71-80']
test['Age']=pd.cut(test['Age'],bins=bins,labels=labels)
test['Age']=lb_age.transform(test['Age'])

# %%
test['City']=test['City'].apply(change_city).values

# %%
c=0
for i in test['Working Professional or Student']:
    if i == "Student":
        test['Profession'][c]="Student"
    c+=1
test['Profession']=test['Profession'].fillna('others')
test['Profession']=test['Profession'].map(dict_profession)

# %%
c=0
for i in test['Academic Pressure']:
    if math.isnan(i) == False:
        test['Work Pressure'][c]=test['Academic Pressure'][c]
    c+=1
test['Work Pressure']=test['Work Pressure'].fillna(3.0)

# %%
c=0

for i in test['Study Satisfaction']:
    if math.isnan(i) == False:
        test['Job Satisfaction'][c]=i
    c+=1

test['Job Satisfaction']=test['Job Satisfaction'].fillna(3.0)

# %%
test['Sleep Duration']=test['Sleep Duration'].apply(change_sleep).values

# %%
test['Dietary Habits']=test['Dietary Habits'].fillna('Moderate')   
test['Dietary Habits']=test['Dietary Habits'].apply(change_diet)

# %%
test['Have you ever had suicidal thoughts ?']=test['Have you ever had suicidal thoughts ?'].map({'No':0,'Yes':1})

# %%
test['Family History of Mental Illness']=test['Family History of Mental Illness'].map({'No':0,'Yes':1})

# %%
print(x.columns)
# Out:
# Index(['Gender', 'Age', 'City', 'Profession', 'Work Pressure',
#        'Job Satisfaction', 'Sleep Duration', 'Dietary Habits',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness'],
#       dtype='object')

# %%
df=test[x.columns]

# %%
#test['Depression']=final_model_ml.predict(df)

# %%
# for dl
y_pred=classifier.predict(df)
y_pred=(y_pred>0.5)
test['Depression']=y_pred
test['Depression']=test['Depression'].astype(int)
# Out:
# 2932/2932 [==============================] - 2s 794us/step

# %% [markdown]
# For result.csv

# %%
res={'id':test['id'],'Depression':test['Depression']}

# %%
res=pd.DataFrame(res)

# %%
res.to_csv('result.csv',index=False)
